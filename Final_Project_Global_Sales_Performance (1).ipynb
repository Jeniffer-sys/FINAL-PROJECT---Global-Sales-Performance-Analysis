# %% [markdown]
# # 📝 1. Introduction of Global Sales Performance
#
# **Global Sales Performance Dataset** - It provides a comprehensive view of worldwide sales transactions across different products, regions, and customer segments. Beyond simple sales counts, this dataset captures key **financial indicators** such as revenue, unit price, quantity sold, and overall transaction value, making it especially useful for **financial performance and profitability analysis**.
#
# In the finance domain, analyzing global sales data helps answer critical business questions such as:
# - Which **products** generate the highest revenue and profit margins?
# - Which **regions** are the most profitable and which ones underperform?
# - How do sales trends vary across time, and what does this mean for financial planning?
# - Are there any patterns or anomalies in sales that could signal risks or opportunities?
#
# By performing **data preprocessing, exploratory data analysis (EDA), and financial visualizations**, this study will focus on uncovering:
# - **Profitability by product category** (e.g., which product lines are most financially successful)
# - **Regional financial performance** (e.g., top revenue-generating markets vs. low-performing regions)
# - **Trends and correlations among financial metrics** such as unit price, sales quantity, and total revenue
#
# The ultimate objective is to provide a clear picture of **global sales performance from a financial perspective**, enabling data-driven strategies for **profit optimization, resource allocation, and market expansion**.

# %% [markdown]
# # 📊 2. Dataset Description
#
# The **Global Sales Performance Dataset** contains structured records of sales transactions collected from multiple regions and product categories.
# It consists of **rows**, where each row represents a unique sales transaction, and **columns**, which capture different attributes of the sale such as product details, customer information, location, and financial metrics.
#
# I have used this dataset from Kaggle: [Global Sales Performance Dataset]
# [https://www.kaggle.com/datasets/shohinurpervezshohan/global-sales-performance-dataset]
#
# - Rows: Each row corresponds to one sales transaction
# - Columns: Include categorical data (e.g., product, region, category), numerical data (e.g., quantity, unit price, revenue), and temporal data (e.g., order date)
# - Data Types: A mix of numerical (integers, floats), categorical (strings), and date/time values
#
# This dataset is well suited for both operational and financial analyses. It supports exploration of:
# - Revenue patterns by product, region, and customer segment
# - Profitability performance across different market dimensions
# - Time-based sales trends to identify seasonality or temporal growth
# - Price–quantity relationships to infer pricing strategy impacts

# %% [markdown]
# # 🏷️ Attribute Information :
#
# The dataset contains 11 attributes (columns). Each attribute is described below along with its significance for sales and financial analysis:
#
# 1. **Region**
#    - Type: Categorical (string)
#    - Description: Geographical area where the sales were made (e.g., East, West, North, South).
#    - Relevance: Helps analyze regional performance, compare sales territories, and optimize resource allocation.
#
# 2. **Salesperson**
#    - Type: Categorical (string)
#    - Description: Name or identifier of the salesperson responsible for the sales..
#    - Relevance: Useful for tracking individual performance, incentive planning, and identifying training needs..
#
# 3. **Revenue**
#    - Type: Numerical (integer)
#    - Description: Total income generated from sales before deducting expenses.
#    - Relevance: Key measure of sales performance, supports forecasting, and helps evaluate sales growth..
#
# 4. **Profit**
#    - Type: Numerical (integer)
#    - Description: Net gain after deducting costs from revenue.
#    - Relevance: Indicates business profitability, helps identify high- vs. low-margin products/regions, and supports pricing decisions.
#
# 5. **Units_Sold**
#    - Type: Numerical (integer)
#    - Description: Number of product units sold.
#    - Relevance: Helps measure sales volume, understand demand trends, and plan inventory.
#
# 6. **Customer_Satisfaction**
#    - Type: Numerical (float)
#    - Description: Customer rating or satisfaction score (e.g., scale of 1–5 or 1–10).
#    - Relevance: Reflects customer experience, helps identify areas of improvement, and correlates with customer retention.
#
# 7. **Marketing_Spend**
#    - Type: Numerical (integer)
#    - Description: Money spent on marketing activities to drive sales.
#    - Relevance: Allows calculation of return on marketing investment (ROMI), measures campaign effectiveness, and links spend to sales outcomes.
#
# 8. **Discount_Percentage**
#    - Type: Numerical (float/percentage)
#    - Description: Discount applied on sales price (in percentage).
#    - Relevance: Influences sales volume and profit margins; helps assess discount strategies.
#
# 9. **Product_Category**
#    - Type: Categorical (string)
#    - Description: Classification of products (e.g., Electronics, Furniture, Clothing).
#    - Relevance: Enables product portfolio analysis, identifies best-selling categories, and guides strategic investments.
#
# 10. **Sales_Channel**
#     - Type: Categorical (string)
#     - Description: Channel through which sales were made (e.g., Online, Retail, Distributor).
#     - Relevance: Helps compare performance across channels, evaluate effectiveness, and plan distribution strategy.
#
# 11. **Order_Processing_Time**
#     - Type: Numerical (integer)
#     - Description: Time taken to process an order (likely in days).
#     - Relevance: Indicates operational efficiency, impacts customer satisfaction, and helps optimize supply chain performance.

# %% [markdown]
# # 💻 3. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 📂 4. Import Dataset

# %%
# Load dataset

df = pd.read_csv("large_sales_data.csv")

df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %% [markdown]
# # 🔍 5. Exploratory Data Analysis (EDA)
#
# Explore the data to gain inights about the data

# %%
# view Dataset info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region                 1000 non-null   object
#  1   Salesperson            1000 non-null   object
#  2   Revenue                1000 non-null   int64
#  3   Profit                 1000 non-null   int64
#  4   Units_Sold             1000 non-null   int64
#  5   Customer_Satisfaction  1000 non-null   float64
#  6   Marketing_Spend        1000 non-null   int64
#  7   Discount_Percentage    1000 non-null   float64
#  8   Product_Category       1000 non-null   object
#  9   Sales_Channel          1000 non-null   object
#  10  Order_Processing_Time  1000 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 86.1+ KB

# %%
# View dimension of dataset

df.shape
# Out:
# (1000, 11)

# %%
# Missing values

print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Region                   0
# Salesperson              0
# Revenue                  0
# Profit                   0
# Units_Sold               0
# Customer_Satisfaction    0
# Marketing_Spend          0
# Discount_Percentage      0
# Product_Category         0
# Sales_Channel            0
# Order_Processing_Time    0
# dtype: int64

# %% [markdown]
# We observe that the dataset contains no missing values

# %%
# Duplicates

print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# We can see that there are no duplicat values in the dataset

# %%
# Data types

df.dtypes
# Out:
# Region                    object
# Salesperson               object
# Revenue                    int64
# Profit                     int64
# Units_Sold                 int64
# Customer_Satisfaction    float64
# Marketing_Spend            int64
# Discount_Percentage      float64
# Product_Category          object
# Sales_Channel             object
# Order_Processing_Time      int64
# dtype: object

# %% [markdown]
# This helps us identify mixed data types in the dataset

# %%
# Summary statistics

df.describe(include="all").T
# Out:
#                         count unique       top freq        mean           std  \
# Region                   1000      4      West  280         NaN           NaN
# Salesperson              1000      5     Alice  213         NaN           NaN
# Revenue                1000.0    NaN       NaN  NaN  107315.608  55015.118415
# Profit                 1000.0    NaN       NaN  NaN   23973.118  14067.263525
# Units_Sold             1000.0    NaN       NaN  NaN     498.594    282.337202
# Customer_Satisfaction  1000.0    NaN       NaN  NaN     2.96342      1.147817
# Marketing_Spend        1000.0    NaN       NaN  NaN   10181.017   5648.219494
# Discount_Percentage    1000.0    NaN       NaN  NaN    14.98931       8.66553
# Product_Category         1000      5  Clothing  210         NaN           NaN
# Sales_Channel            1000      3    Online  344         NaN           NaN
# Order_Processing_Time  1000.0    NaN       NaN  NaN       4.963      2.625362
#
# ...

# %%
col_names = df.columns
col_names
# Out:
# Index(['Region', 'Salesperson', 'Revenue', 'Profit', 'Units_Sold',
#        'Customer_Satisfaction', 'Marketing_Spend', 'Discount_Percentage',
#        'Product_Category', 'Sales_Channel', 'Order_Processing_Time'],
#       dtype='object')

# %% [markdown]
# The output lists the column names

# %%
# Remove Leading Spaces from column names

df.columns = df.columns.str.strip()

# %% [markdown]
# Removed the leading space from the column names.Lets again view the columns

# %%
# View Column name again

df.columns
# Out:
# Index(['Region', 'Salesperson', 'Revenue', 'Profit', 'Units_Sold',
#        'Customer_Satisfaction', 'Marketing_Spend', 'Discount_Percentage',
#        'Product_Category', 'Sales_Channel', 'Order_Processing_Time'],
#       dtype='object')

# %%
# Percentage of missing values

missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.sort_values(ascending=False)
# Out:
# Region                   0.0
# Salesperson              0.0
# Revenue                  0.0
# Profit                   0.0
# Units_Sold               0.0
# Customer_Satisfaction    0.0
# Marketing_Spend          0.0
# Discount_Percentage      0.0
# Product_Category         0.0
# Sales_Channel            0.0
# Order_Processing_Time    0.0
# dtype: float64

# %%
# Generating basic statistical summary for numerical columns

df.describe()
# Out:
#              Revenue        Profit   Units_Sold  Customer_Satisfaction  \
# count    1000.000000   1000.000000  1000.000000            1000.000000
# mean   107315.608000  23973.118000   498.594000               2.963420
# std     55015.118415  14067.263525   282.337202               1.147817
# min     10163.000000   1097.000000    10.000000               1.000000
# 25%     58297.750000  11633.750000   256.000000               1.950000
# 50%    108841.000000  23020.500000   502.500000               2.950000
# 75%    155577.750000  35622.500000   738.500000               3.960000
# max    199784.000000  49980.000000   999.000000               5.000000
#
#        Marketing_Spend  Discount_Percentage  Order_Processing_Time
# count      1000.000000           1000.00000            1000.000000
# mean      10181.017000             14.98931               4.963000
# std        5648.219494              8.66553               2.625362
# ...

# %% [markdown]
# The output shows the statistical summary for the numerical columns

# %% [markdown]
# # 🔢 Summary of numberical Variables

# %% [markdown]
# - The dataset contains a total of 7 numerical variables.
# - Out of these, 6 variables are continuous: Revenue, Profit, Units_Sold, Customer_Satisfaction, Marketing_Spend, and Discount_Percentage.
# - There is 1 discrete variable in the dataset, which is Order_Processing_Time.
# - Continuous variables change over a wide range and show detailed values.
# - The discrete variable takes limited values and is useful for grouping the data.

# %% [markdown]
# # 📂 A.Data Loading and Initial Overview
#
# - The dataset is imported using **Pandas**.
# - We check the **number of rows and columns** to understand the dataset size.
# - We look at the **data types of each column** to identify numerical and categorical variables.
# - Initial observations are made using:
#   - `head()` → shows the first few rows.
#   - `info()` → provides column data types and non-null counts.
#   - `describe()` → gives statistical summary for numerical variables.

# %%
# Import pandas

import pandas as pd

# %%
# Load the dataset

df = pd.read_csv("large_sales_data.csv")

# %%
# Shape of the dataset

print("Number of rows and columns:", df.shape)
# Out:
# Number of rows and columns: (1000, 11)

# %%
# Data types of each column

print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Region                    object
# Salesperson               object
# Revenue                    int64
# Profit                     int64
# Units_Sold                 int64
# Customer_Satisfaction    float64
# Marketing_Spend            int64
# Discount_Percentage      float64
# Product_Category          object
# Sales_Channel             object
# Order_Processing_Time      int64
# dtype: object

# %%
# First five rows

print("\nFirst 5 rows:")
display(df.head())
# Out:
# First 5 rows:
#   Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0   East       Alice   137118   10067         219                   4.06
# 1   West       Alice    78577   38481         750                   2.64
# 2  North       Alice    19078   28037         406                   3.62
# 3   East         Eve   166075   10557         109                   2.04
# 4   East       David    72768   10435          40                   1.64
#
#    Marketing_Spend  Discount_Percentage Product_Category Sales_Channel  \
# 0            14666                13.40        Furniture        Retail
# 1             8254                 3.70       Automobile     Wholesale
# 2            14746                 6.18        Furniture        Retail
# 3             4578                 0.03        Furniture        Online
# 4            13353                 1.18      Electronics     Wholesale
#
#    Order_Processing_Time
# 0                      1
# 1                      3
# ...

# %%
# Dataset info

print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region                 1000 non-null   object
#  1   Salesperson            1000 non-null   object
#  2   Revenue                1000 non-null   int64
#  3   Profit                 1000 non-null   int64
#  4   Units_Sold             1000 non-null   int64
#  5   Customer_Satisfaction  1000 non-null   float64
#  6   Marketing_Spend        1000 non-null   int64
#  7   Discount_Percentage    1000 non-null   float64
#  8   Product_Category       1000 non-null   object
#  9   Sales_Channel          1000 non-null   object
#  10  Order_Processing_Time  1000 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 86.1+ KB

# %% [markdown]
# # 🧹B. Data Pre-processing

# %% [markdown]
# In this step, we clean and prepare the dataset for analysis. The following tasks are performed:
#
# - **Handling missing values** → Check for missing data and decide whether to fill or remove them.
# - **Removing duplicates** → Drop duplicate records to ensure data accuracy.
# - **Correcting data types** → Convert columns to appropriate types (e.g., numerical, categorical, datetime).
# - **Creating derived columns** → Generate new useful columns from existing ones.
# - **Filtering or aggregating data** → Remove unnecessary rows or summarize data for analysis.

# %% [markdown]
# ## 🧩 1. Handling missing values

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Region                   0
# Salesperson              0
# Revenue                  0
# Profit                   0
# Units_Sold               0
# Customer_Satisfaction    0
# Marketing_Spend          0
# Discount_Percentage      0
# Product_Category         0
# Sales_Channel            0
# Order_Processing_Time    0
# Profit_Margin            0
# Revenue_per_Unit         0
# dtype: int64

# %%
# Example: Fill numeric missing values with mean (if any)

df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %%
# Fill categorical missing values with mode (fixed version)

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ## 🗑️ 2. Removing duplicates

# %%
print("\nNumber of duplicate rows:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %% [markdown]
# ## 🔤 3. Correcting data types

# %%
#Example: Convert 'Order_Processing_Time' to categorical if needed

df['Order_Processing_Time'] = df['Order_Processing_Time'].astype('category')

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %% [markdown]
# ## 🧮 4. Creating derived columns

# %%
# Example: Create Profit Margin column

df['Profit_Margin'] = (df['Profit'] / df['Revenue']) * 100

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %%
# Example: Create Revenue per Unit column

df['Revenue_per_Unit'] = df['Revenue'] / df['Units_Sold']

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %% [markdown]
# ## 📊 5. Filtering or Aggregating data

# %%
# Example: Filter out rows where Units_Sold is 0 or negative
df = df[df['Units_Sold'] > 0]

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %%
# Example: Aggregate total revenue by region

region_revenue = df.groupby('Region')['Revenue'].sum().reset_index()

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %%
# Display a few rows after preprocessing

print("\nData after preprocessing:")
display(df.head())
# Out:
# Data after preprocessing:
#   Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0   East       Alice   137118   10067         219                   4.06
# 1   West       Alice    78577   38481         750                   2.64
# 2  North       Alice    19078   28037         406                   3.62
# 3   East         Eve   166075   10557         109                   2.04
# 4   East       David    72768   10435          40                   1.64
#
#    Marketing_Spend  Discount_Percentage Product_Category Sales_Channel  \
# 0            14666                13.40        Furniture        Retail
# 1             8254                 3.70       Automobile     Wholesale
# 2            14746                 6.18        Furniture        Retail
# 3             4578                 0.03        Furniture        Online
# 4            13353                 1.18      Electronics     Wholesale
#
#   Order_Processing_Time  Profit_Margin  Revenue_per_Unit
# ...

# %% [markdown]
# # 🔬 After Data Pre-processing

# %%
df
# Out:
#     Region Salesperson  Revenue  Profit  Units_Sold  Customer_Satisfaction  \
# 0     East       Alice   137118   10067         219                   4.06
# 1     West       Alice    78577   38481         750                   2.64
# 2    North       Alice    19078   28037         406                   3.62
# 3     East         Eve   166075   10557         109                   2.04
# 4     East       David    72768   10435          40                   1.64
# ..     ...         ...      ...     ...         ...                    ...
# 995  North       David   155047    6355          97                   2.52
# 996  North         Bob    72424   10083         845                   3.43
# 997   West         Bob    55603   39342         997                   2.55
# 998   West         Bob   164324   21456         216                   1.96
# 999   East         Bob   142503   14324         138                   1.38
#
# ...

# %% [markdown]
# # 🔍 C.Exploratory Data Analysis (EDA)
#   ## Conduct descriptive and exploratory analysis to uncover patterns and trends:

# %% [markdown]
# ## Univariate Analysis

# %%
# Revenue distribution
sns.histplot(df["Revenue"], bins=30, kde=True, color="skyblue")
plt.title("Revenue Distribution")
plt.show()

# %%
# Profit distribution
sns.histplot(df["Profit"], bins=30, kde=True, color="orange")
plt.title("Profit Distribution")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# Revenue vs Profit
sns.scatterplot(x="Revenue", y="Profit", hue="Region", data=df, alpha=0.7)
plt.title("Revenue vs Profit by Region")
plt.show()

# %%
# Discount vs Profit
sns.scatterplot(x="Discount_Percentage", y="Profit", hue="Product_Category", data=df, alpha=0.7)
plt.title("Discount % vs Profit by Product Category")
plt.show()

# %% [markdown]
# ## Multivariate Analysis (Groupby & Pivot Tables)

# %%
# Pivot: Region × Product Category
pivot_region_category = pd.pivot_table(
    df, values=["Revenue","Profit"],
    index="Region", columns="Product_Category", aggfunc="mean"
)
pivot_region_category
# Out:
#                         Profit                                            \
# Product_Category    Automobile      Clothing   Electronics     Furniture
# Region
# East              20935.771429  23455.883721  22364.428571  24506.617021
# North             24103.039216  23204.915254  22128.500000  25319.408163
# South             24836.020408  21730.695652  22832.456522  25132.644444
# West              29462.818182  23547.048387  22103.637931  26936.660377
#
#                                       Revenue                                \
# Product_Category       Grocery     Automobile       Clothing    Electronics
# Region
# East              23504.793103  111505.400000  118382.813953  108310.244898
# North             22078.177778  110413.352941  109211.271186  117026.018519
# South             25258.636364   95484.551020  110275.326087  102882.152174
# West              24886.903846  103810.618182   98463.290323  117476.396552
#
#
# Product_Category      Furniture        Grocery
# ...

# %% [markdown]
# ## Correlation Analysis

# %%
# Correlation heatmap
corr = df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0, fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# # 📊 D. Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ## Bar plot - Revenue by Region

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    x="Region",
    y="Revenue",
    data=df,
    estimator=sum,
    errorbar=None,          # replaces ci=None
    hue="Region",           # needed when using palette
    palette="viridis",
    legend=False            # avoid duplicate legends
)
plt.title("Total Revenue by Region")
plt.xlabel("Region")
plt.ylabel("Total Revenue")
plt.show()

# %% [markdown]
# ## Line chart - Average Profit by Order Processing Time

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x="Order_Processing_Time", y="Profit", data=df, estimator="mean", marker="o", color="orange")
plt.title("Average Profit vs Order Processing Time")
plt.xlabel("Order Processing Time (days)")
plt.ylabel("Average Profit")
plt.show()

# %% [markdown]
# ## Pie chart - Sales Channel distribution

# %%
sales_channel_counts = df["Sales_Channel"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(sales_channel_counts, labels=sales_channel_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title("Sales Channel Distribution")
plt.show()

# %% [markdown]
# ## Histogram - Distribution of Revenue

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["Revenue"], bins=30, kde=True, color="blue")
plt.title("Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Box plot - Profit by Product Category

# %%
plt.figure(figsize=(10,6))
sns.boxplot(
    x="Product_Category",
    y="Profit",
    data=df,
    hue="Product_Category",
    palette="Set3",
    legend=False
)
plt.title("Profit Distribution by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# ## Scatter plot - Revenue vs Profit

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="Revenue", y="Profit", hue="Region", data=df, palette="tab10", alpha=0.7)
plt.title("Revenue vs Profit (Colored by Region)")
plt.xlabel("Revenue")
plt.ylabel("Profit")
plt.legend(title="Region")
plt.show()

# %% [markdown]
# ## Heatmap - Correlation Matrix

# %%
plt.figure(figsize=(10,8))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Subplots - Revenue and Profit distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,6))
sns.histplot(df["Revenue"], bins=30, kde=True, color="blue", ax=axes[0])
axes[0].set_title("Revenue Distribution")
axes[0].set_xlabel("Revenue")
axes[0].set_ylabel("Frequency")

sns.histplot(df["Profit"], bins=30, kde=True, color="green", ax=axes[1])
axes[1].set_title("Profit Distribution")
axes[1].set_xlabel("Profit")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 📌 Insight Generation and Report

# %% [markdown]
# In this section, we summarize the **key insights** from the analysis.
# We use Markdown cells to explain the logic, methods, and interpretation of results.
# The main focus is to highlight **significant patterns, correlations, or anomalies** observed in the dataset.

# %% [markdown]
# # 💡 Key Insights

# %% [markdown]
# 1. **Revenue & Profit Trends**
#    - Revenue and Profit are positively correlated.
#    - Certain regions and product categories contribute significantly higher profits than others.
#
# 2. **Regional Performance**
#    - The East and West regions show higher revenue generation compared to others.
#    - Some regions have lower profit margins due to high discounts or marketing spend.
#
# 3. **Impact of Discounts & Marketing Spend**
#    - Discounts influence sales volume but reduce overall profit if not controlled.
#    - Optimized marketing spend improves revenue, but overspending lowers efficiency.
#
# 4. **Customer Satisfaction**
#    - Higher satisfaction scores are generally linked with higher revenue and repeat sales.
#    - Some products show good revenue but lower satisfaction, indicating improvement areas.
#
# 5. **Anomalies**
#    - Outliers were found in Revenue and Profit values, suggesting either exceptional deals or potential data recording issues.

# %% [markdown]
#  # 🎯 Conclusion & Recommendations
#
#
# In summary, the analysis of the Global Sales Performance dataset provided useful insights into sales and financial outcomes. The study highlighted how revenue, profit, and marketing spend vary across regions, product categories, and sales channels. Correlation analysis showed clear relationships between key financial metrics, such as revenue and profit.
#
# - Overall, the dataset reveals that revenue and profit strongly depend on region, product category, and sales channel.
# - Discounts and marketing spend play a critical role in shaping profitability.
# - Customer satisfaction shows potential to drive long-term financial growth.
#
# **Recommendations:**
# - Focus on high-performing regions and products to maximize profit.
# - Optimize discount and marketing strategies to balance sales growth and profitability.
# - Address areas with low customer satisfaction to improve loyalty.
# - Consider predictive modeling to forecast future sales performance.
